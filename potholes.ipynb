# %% [markdown]
# <a href="https://colab.research.google.com/github/advaith-22/glitch/blob/main/potholes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python train.py --workers 1 --device 0 --batch-size 4 --epochs 20 --img 640 640 --data data/custom.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7custom.yaml --name yolov7 --weights yolov7.pt
# Out:
# YOLOR 🚀 2023-1-21 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=4, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7custom.yaml', data='data/custom.yaml', device='0', entity=None, epochs=20, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov74', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=4, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=1, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --weights runs/train/yolov74/weights/best.pt --conf 0.5 --img-size 640 --source data/val/images/img-104_jpg.rf.687b8858a9a79e92ea4b11024eafee62.jpg --no-trace
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=True, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='data/val/images/img-104_jpg.rf.687b8858a9a79e92ea4b11024eafee62.jpg', update=False, view_img=False, weights=['runs/train/yolov74/weights/best.pt'])
# YOLOR 🚀 2023-1-21 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
